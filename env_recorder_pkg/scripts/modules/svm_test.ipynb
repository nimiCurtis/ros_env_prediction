# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

# Load the dataset
X = # features
y = # labels

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Define the model
model = SVC()

# Define the parameter grids for the models
param_grid_1 = {'C': [0.1, 1, 10, 100],
                'gamma': [1, 0.1, 0.01, 0.001],
                'kernel': ['rbf']}
param_grid_2 = {'C': [0.1, 1, 10, 100],
                'gamma': [1, 0.1, 0.01, 0.001],
                'kernel': ['linear']}

# Create a grid search object using the model and parameter grid
grid_1 = GridSearchCV(model, param_grid_1, verbose=2)
grid_2 = GridSearchCV(model, param_grid_2, verbose=2)

# Fit the grid search objects to the training data
grid_1.fit(X_train, y_train)
grid_2.fit(X_train, y_train)

# Make predictions on the test data
predictions_1 = grid_1.predict(X_test)
predictions_2 = grid_2.predict(X_test)

# Print the scores for each model
print(f"Model 1 score: {grid_1.best_score_}")
print(f"Model 2 score: {grid_2.best_score_}")

# Print the classification reports for each model
print("Model 1 Classification Report:")
print(classification_report(y_test, predictions_1))
print("Model 2 Classification Report:")
print(classification_report(y_test, predictions_2))

# %%
# %matplotlib inline
import warnings
warnings.simplefilter("ignore")
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn import set_config
set_config(display='diagram')
from joblib import dump, load
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from typing import Any


from env_classifier.env_classifier import EnvClassifierPipe

env_clf_pipe = EnvClassifierPipe()
env_clf_pipe.pipe = Pipeline([('scaler', StandardScaler()),('model', SVC())])
env_clf_pipe.pipe
# Out:
# Pipeline(steps=[('scaler', StandardScaler()), ('model', SVC())])

# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV

# Load the dataset
X = # features
y = # labels

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Define the model
model = SVC()

# Define the parameter grid for the model
param_grid = {'C': [0.1, 1, 10, 100],
              'gamma': [1, 0.1, 0.01, 0.001],
              'kernel': ['rbf', 'linear']}

# Create a grid search object using the model and parameter grid
grid = GridSearchCV(model, param_grid, verbose=2)

# Fit the grid search object to the training data
grid.fit(X_train, y_train)

# Make predictions on the test data
predictions = grid.predict(X_test)

# Print the best model and its score
best_model = grid.best_estimator_
best_score = grid.best_score_
print(f"Best model: {best_model}")
print(f"Best score: {best_score}")

# Save the best model and its score
import pickle
with open("best_model.pkl", "wb") as f:
    pickle.dump(best_model, f)
with open("best_score.pkl", "wb") as f:
    pickle.dump(best_score, f)

# %%
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

# Load the dataset
X = # features
y = # labels

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Define the models
svm_model = SVC()
knn_model = KNeighborsClassifier()
rf_model = RandomForestClassifier()

# Define the parameter grids for the models
svm_param_grid = {'C': [0.1, 1, 10, 100],
                  'gamma': [1, 0.1, 0.01, 0.001],
                  'kernel': ['rbf']}
knn_param_grid = {'n_neighbors': [3, 5, 7, 9, 11]}
rf_param_grid = {'n_estimators': [10, 50, 100, 200],
                 'max_depth': [None, 5, 10, 15]}

# Create a grid search object for each model using the corresponding parameter grid
svm_grid = GridSearchCV(svm_model, svm_param_grid, verbose=2)
knn_grid = GridSearchCV(knn_model, knn_param_grid, verbose=2)
rf_grid = GridSearchCV(rf_model, rf_param_grid, verbose=2)

# Fit the grid search objects to the training data
svm_grid.fit(X_train, y_train)
knn_grid.fit(X_train, y_train)
rf_grid.fit(X_train, y_train)

# Make predictions on the test data using each model
svm_predictions = svm_grid.predict(X_test)
knn_predictions = knn_grid.predict(X_test)
rf_predictions = rf_grid.predict(X_test)

# Print the scores for each model
print(f"SVM model score: {svm_grid.best_score_}")
print(f"k-NN model score: {knn_grid.best_score_}")
print(f"Random Forest model score: {rf_grid.best_score_}")

# Print the classification reports for each model
print("SVM Classification Report:")
print(classification_report(y_test, svm_predictions))
print("k-NN Classification Report:")
print(classification_report(y_test, knn_predictions))
print("Random Forest Classification Report:")
print(classification_report(y_test, rf_predictions))

# Determine the best model
best_model = max(svm_grid, knn_grid, rf_grid, key=lambda x: x.best_score

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

# Load the dataset
X = # features
y = # labels

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Define the models and their parameter grids
svm_model = SVC()
svm_param_grid = {'C': [0.1, 1, 10, 100],
                  'gamma': [1, 0.1, 0.01, 0.001],
                  'kernel': ['rbf']}
knn_model = KNeighborsClassifier()
knn_param_grid = {'n_neighbors': [3, 5, 7, 9, 11]}
rf_model = RandomForestClassifier()
rf_param_grid = {'n_estimators': [10, 50, 100, 200],
                 'max_depth': [None, 5, 10, 15]}

# Define the pipeline for each model
svm_pipeline = Pipeline([('scaler', StandardScaler()),
                         ('model', svm_model)])
knn_pipeline = Pipeline([('scaler', StandardScaler()),
                         ('model', knn_model)])
rf_pipeline = Pipeline([('scaler', StandardScaler()),
                        ('model', rf_model)])

# Create a grid search object for each pipeline using the corresponding parameter grid
svm_grid = GridSearchCV(svm_pipeline, svm_param_grid, verbose=2)
knn_grid = GridSearchCV(knn_pipeline, knn_param_grid, verbose=2)
rf_grid = GridSearchCV(rf_pipeline, rf_param_grid, verbose=2)

# Fit the grid search objects to the training data
svm_grid.fit(X_train, y_train)
knn_grid.fit(X_train, y_train)
rf_grid.fit(X_train, y_train)

# Make predictions on the test data using each pipeline
svm_predictions = svm_grid.predict(X_test)
knn_predictions = knn_grid.predict(X_test)
rf_predictions = rf_grid.predict(X_test)

# Print the scores for each model
print(f"SVM model score: {svm_grid.best_score_}")
print(f"k-NN model score: {knn_grid.best_score_}")
print(f"Random Forest model score: {rf_grid.best_score_}")

# Print the classification reports for
